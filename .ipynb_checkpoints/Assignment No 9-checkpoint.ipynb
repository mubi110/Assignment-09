# %%
import numpy as np
import pandas as pd

# %%
array1 = np.array([22,43,23,45,65,75,9])
array2 = np.array([87,32,45,35,2,76,96,])

# %%
addition = array1 + array2
subtraction = array1 - array2
multiplication = array1 * array2
division = array1 / array2

print("Addition of Array 1 & Array2:", addition)
print("Subtraction of Array 1 & Array2:", subtraction)
print("Multiplication of Array 1 & Array2:", multiplication)
print("Division of Array 1 & Array2:", division)
# Out:
# Addition of Array 1 & Array2: [109  75  68  80  67 151 105]
# Subtraction of Array 1 & Array2: [-65  11 -22  10  63  -1 -87]
# Multiplication of Array 1 & Array2: [1914 1376 1035 1575  130 5700  864]
# Division of Array 1 & Array2: [ 0.25287356  1.34375     0.51111111  1.28571429 32.5         0.98684211
#   0.09375   ]

# %%
df = pd.read_csv('retail supermarket.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
df.tail(2)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category   Sales  Quantity  \
# 9992        92627   West  Office Supplies        Paper   29.60         4
# 9993        92683   West  Office Supplies   Appliances  243.16         2
#
#       Discount  Profit
# 9992       0.0  13.320
# 9993       0.0  72.948

# %%
df.loc[0]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Postal Code             42420
# Region                  South
# Category            Furniture
# Sub-Category        Bookcases
# Sales                  261.96
# Quantity                    2
# Discount                  0.0
# Profit                41.9136
# Name: 0, dtype: object

# %%
df.loc[45:50,'City':'Quantity']
# Out:
#           City      State  Postal Code   Region         Category Sub-Category  \
# 45       Eagan  Minnesota        55122  Central  Office Supplies      Binders
# 46    Westland   Michigan        48185  Central  Office Supplies      Storage
# 47       Dover   Delaware        19901     East       Technology  Accessories
# 48       Dover   Delaware        19901     East       Technology       Phones
# 49  New Albany    Indiana        47150  Central  Office Supplies      Binders
# 50  New Albany    Indiana        47150  Central  Office Supplies       Labels
#
#      Sales  Quantity
# 45   17.46         2
# 46  211.96         4
# 47   45.00         3
# 48   21.80         2
# 49   38.22         6
# 50   75.18         6

# %%
df.iloc[47]
# Out:
# Ship Mode       Standard Class
# Segment               Consumer
# Country          United States
# City                     Dover
# State                 Delaware
# Postal Code              19901
# Region                    East
# Category            Technology
# Sub-Category       Accessories
# Sales                     45.0
# Quantity                     3
# Discount                   0.0
# Profit                    4.95
# Name: 47, dtype: object

# %%
array3 = np.array([4,5,6,7,10,9,8,11,12])

# %%
np.mean(array3)
# Out:
# 8.0

# %%
np.median(array3)
# Out:
# 8.0

# %%
np.var(array3)
# Out:
# 6.666666666666667

# %%
np.std(array3)
# Out:
# 2.581988897471611

# %%
arr_int = np.array([3,5,6,4,7,8,6,2])
arr_float = np.array([2.5,7.6,7.7,8.3,8.2,4.4,5.2,4.9])
arr_bool = np.array([True,False,False,True,False,True,True,False])

# %%
arr1 = np.array([1,3,8,5,3])
arr2 = np.array([3,6,7,8,9])

# %%
conc_arr = np.concatenate((arr1,arr2))
conc_arr
# Out:
# array([1, 3, 8, 5, 3, 3, 6, 7, 8, 9])

# %%
sort_asc = np.sort(arr1)
sort_asc
# Out:
# array([1, 3, 3, 5, 8])

# %%
sort_desc = np.sort(arr1)[::-1]
sort_desc
# Out:
# array([8, 5, 3, 3, 1])
